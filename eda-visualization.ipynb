# %%
# import necessary packages

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# to get a info of what the data looks like
# to get a sense of the distribution, shape, data types, and type of information
# Lastly, this step helps us to identify whether there are additional variables that can be created from transforming or combining existing variables, such as in feature engineering.

# %%
df = pd.read_csv('dataset/transformed-googleplaystore.csv')

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#     Reviews     Size    Installs  Type  Price Content Rating  \
# 0     159.0  19456.0     10000.0  Free    0.0       Everyone
# 1     967.0  14336.0    500000.0  Free    0.0       Everyone
# 2   87510.0   8908.8   5000000.0  Free    0.0       Everyone
# 3  215644.0  25600.0  50000000.0  Free    0.0           Teen
# 4     967.0   2867.2    100000.0  Free    0.0       Everyone
#
#                       Genres Last Updated         Current Ver   Android Ver
# ...

# %%
df.info()
# df.shape
# df.dtypes
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10840 entries, 0 to 10839
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10840 non-null  object
#  1   Category        10840 non-null  object
#  2   Rating          10840 non-null  float64
#  3   Reviews         10840 non-null  float64
#  4   Size            10840 non-null  float64
#  5   Installs        10840 non-null  float64
#  6   Type            10840 non-null  object
#  7   Price           10840 non-null  float64
#  8   Content Rating  10840 non-null  object
#  9   Genres          10840 non-null  object
#  10  Last Updated    10840 non-null  object
#  11  Current Ver     10832 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(5), object(8)
# memory usage: 1.1+ MB

# %% [markdown]
# a summary table is very useful for analyzing numerical values within our dataset. In Python, these summary tables present statistics that summarize the central tendency, dispersion, and shape of the distribution of our dataset. The statistics covered include the count of non-empty records, mean, standard deviation, minimum, maximum, 25th percentile, 50th percentile and 75th percentile.

# %%
df.describe()
# Out:
#              Rating       Reviews           Size      Installs         Price
# count  10840.000000  1.084000e+04   10840.000000  1.084000e+04  10840.000000
# mean       4.191972  4.441529e+05   20348.725175  1.546434e+07      1.027368
# std        0.478907  2.927761e+06   21602.788178  8.502936e+07     15.949703
# min        1.000000  0.000000e+00       8.500000  0.000000e+00      0.000000
# 25%        4.100000  3.800000e+01    6041.600000  1.000000e+03      0.000000
# 50%        4.200000  2.094000e+03   11264.000000  1.000000e+05      0.000000
# 75%        4.500000  5.477550e+04   26624.000000  5.000000e+06      0.000000
# max        5.000000  7.815831e+07  102400.000000  1.000000e+09    400.000000

# %%
df.describe(include='object')
# Out:
#            App Category   Type Content Rating Genres Last Updated  \
# count    10840    10840  10840          10840  10840        10840
# unique    9659       33      2              6    119         1377
# top     ROBLOX   FAMILY   Free       Everyone  Tools   2018-08-03
# freq         9     1972  10040           8714    842          326
#
#                Current Ver Android Ver
# count                10832       10838
# unique                2831          33
# top     Varies with device  4.1 and up
# freq                  1459        2451

# %% [markdown]
# Visualization helps to make univariate and bivariate analysis for the variables inside the dataset.
#
# During univariate analysis, our main focus is to examine individual variables in our dataset separately. This analysis allows us to extract various valuable information, such as the median, mode, maximum value, range, and identification of outliers. It is applicable to both categorical and numerical variables, and for each type of variable, there are several chart options available. By utilizing these charts, we can gain insights into the data's underlying distribution and discover any concealed patterns within the dataset. Choosing the appropriate chart for each variable is crucial to ensure the accuracy of our analysis and the meaningful insights we can obtain from it.
#
# The main objective of bivariate analysis is to understand how changes in one variable relate to changes in another variable. It helps to determine if there is a correlation or dependency between the two variables. Bivariate analysis can be applied to both numerical and categorical variables.

# %% [markdown]
# With the histogram, we can quickly identify outliers, data spread, skewness, and more.

# %%
plt.figure(figsize= (12,6))
ax = sns.histplot( data = df, x= df["Rating"])
ax.set_xlabel('Rating',fontsize = 15)
ax.set_ylabel('Count of rating', fontsize = 15)
ax.set_title('Univariate Analysis of Rating', fontsize= 20)
# Out:
# Text(0.5, 1.0, 'Univariate Analysis of Rating')

# %% [markdown]
# Boxplots give us a sense of the underlying distribution of our dataset through five key metrics. The metrics include the minimum, first quartile, median, third quartile, and maximum values.
#
# the spread of the price variable and outliers

# %%
plt.figure(figsize= (12,6))
ax = sns.boxplot(data = df, x= df["Size"])
ax.set_xlabel('App Size in KB',fontsize = 15)
ax.set_title('Univariate analysis of App Size', fontsize= 20)
plt.ticklabel_format(style='plain', axis='x')

# %% [markdown]
# A violin plot is quite like a boxplot because it depicts the distribution of our dataset. The violin plot shows the peak of our data and where most values in our dataset are clustered. Just like boxplots provide summary statistics about our data, violin plots do the same along with providing additional information about the shape of our data.

# %%
plt.figure(figsize= (12,6))
ax = sns.violinplot(data = df, x= df["Size"])
ax.set_xlabel('App Size in KB',fontsize = 15)
ax.set_title('Univariate analysis of App Size', fontsize= 20)
plt.ticklabel_format(style='plain', axis='x')

# %% [markdown]
# the bar chart analyzes categories

# %%
plt.figure(figsize= (12,6))
ax = sns.countplot(data = df, x= df['Category'])
ax.set_xlabel('App Categories',fontsize = 15)
ax.set_ylabel('Count of Category',fontsize = 15)
ax.set_title('Univariate analysis of App Categories', fontsize= 20)

# Rotate the x-axis labels to be readable
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
# Out:
# [Text(0, 0, 'ART_AND_DESIGN'),
#  Text(1, 0, 'AUTO_AND_VEHICLES'),
#  Text(2, 0, 'BEAUTY'),
#  Text(3, 0, 'BOOKS_AND_REFERENCE'),
#  Text(4, 0, 'BUSINESS'),
#  Text(5, 0, 'COMICS'),
#  Text(6, 0, 'COMMUNICATION'),
#  Text(7, 0, 'DATING'),
#  Text(8, 0, 'EDUCATION'),
#  Text(9, 0, 'ENTERTAINMENT'),
#  Text(10, 0, 'EVENTS'),
#  Text(11, 0, 'FINANCE'),
#  Text(12, 0, 'FOOD_AND_DRINK'),
#  Text(13, 0, 'HEALTH_AND_FITNESS'),
#  Text(14, 0, 'HOUSE_AND_HOME'),
#  Text(15, 0, 'LIBRARIES_AND_DEMO'),
#  Text(16, 0, 'LIFESTYLE'),
#  Text(17, 0, 'GAME'),
#  Text(18, 0, 'FAMILY'),
#  Text(19, 0, 'MEDICAL'),
#  Text(20, 0, 'SOCIAL'),
#  Text(21, 0, 'SHOPPING'),
#  Text(22, 0, 'PHOTOGRAPHY'),
#  Text(23, 0, 'SPORTS'),
#  Text(24, 0, 'TRAVEL_AND_LOCAL'),
#  Text(25, 0, 'TOOLS'),
#  Text(26, 0, 'PERSONALIZATION'),
#  Text(27, 0, 'PRODUCTIVITY'),
#  Text(28, 0, 'PARENTING'),
#  Text(29, 0, 'WEATHER'),
#  Text(30, 0, 'VIDEO_PLAYERS'),
#  Text(31, 0, 'NEWS_AND_MAGAZINES'),
# ...

# %% [markdown]
# A pie chart is a circular visual that displays the relative sizes of various categories.

# %%
type_group
# Out:
#    Type    App  Category  Rating  Reviews   Size  Installs  Price  \
# 0  Free  10040     10040   10040    10040  10040     10040  10040
# 1  Paid    800       800     800      800    800       800    800
#
#    Content Rating  Genres  Last Updated  Current Ver  Android Ver
# 0           10040   10040         10040        10034        10039
# 1             800     800           800          798          799

# %%
type_group = df.groupby('Type').count()
type_group = type_group.reset_index()

cols = ['g', 'b']

plt.pie(type_group["App"], labels = type_group['Type'], colors = cols)
plt.title('Univariate Analysis of Types of Apps', fontsize=15)
plt.show()

# %%
# Create subplots with 1 row and 3 columns
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(18, 6))

# Plot 1: Histogram
sns.histplot(data=df, x='Rating', ax=axes[0])
axes[0].set_xlabel('Rating', fontsize=15)
axes[0].set_ylabel('Count of rating', fontsize=15)
axes[0].set_title('Univariate Analysis of Rating', fontsize=20)

# Plot 2: Box Plot
sns.boxplot(data=df, x='Size', ax=axes[1])
axes[1].set_xlabel('App Size in KB', fontsize=15)
axes[1].set_title('Univariate Analysis of App Size', fontsize=20)
axes[1].ticklabel_format(style='plain', axis='x')

# Plot 3: Violin Plot
sns.violinplot(data=df, x='Size', ax=axes[2])
axes[2].set_xlabel('App Size in KB', fontsize=15)
axes[2].set_title('Univariate Analysis of App Size', fontsize=20)
axes[2].ticklabel_format(style='plain', axis='x')

# Adjust the layout to prevent overlapping labels
plt.tight_layout()

# Show the plots
plt.show()

# %%
# Create subplots with 1 row and 2 columns
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(18, 6))

# Plot 1: Countplot
sns.countplot(data=df, x='Category', ax=axes[0])
axes[0].set_xlabel('App Categories', fontsize=15)
axes[0].set_ylabel('Count of Category', fontsize=15)
axes[0].set_title('Univariate analysis of App Categories', fontsize=20)
axes[0].set_xticklabels(axes[0].get_xticklabels(), rotation=90)

# Plot 2: Pie Chart
type_group = df.groupby('Type').count()
type_group = type_group.reset_index()
cols = ['g', 'b']
axes[1].pie(type_group["App"], labels=type_group['Type'], colors=cols)
axes[1].set_title('Univariate Analysis of Types of Apps', fontsize=15)

# Adjust the layout to prevent overlapping labels
plt.tight_layout()

# Show the plots
plt.show()

# %%
#num_columns = ["Rating", "Reviews", "Size", "Installs", "Price"]

for column in df.columns:
    if df[column].dtypes=='float64': 
        # Create subplots with 1 row and 3 columns
        fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(18, 6))

        # Plot 1: Histogram
        sns.histplot(data=df, x=column, ax=axes[0])
        axes[0].set_xlabel('{}'.format(column.capitalize()), fontsize=15)
        axes[0].set_title('Histogram of {}'.format(column.capitalize()), fontsize=20)

        # Plot 2: Box Plot
        sns.boxplot(data=df, x=column, ax=axes[1])
        axes[1].set_xlabel('{}'.format(column.capitalize()), fontsize=15)
        axes[1].set_title('Box Plot of {}'.format(column.capitalize()), fontsize=20)
        axes[1].ticklabel_format(style='plain', axis='x')

        # Plot 3: Violin Plot
        sns.violinplot(data=df, x=column, ax=axes[2])
        axes[2].set_xlabel('{}'.format(column.capitalize()), fontsize=15)
        axes[2].set_title('Violin Plot of {}'.format(column.capitalize()), fontsize=20)
        axes[2].ticklabel_format(style='plain', axis='x')

        # Adjust the layout to prevent overlapping labels
        plt.tight_layout()

        # Show the plots
        plt.show()

# %% [markdown]
# Our boxplot seems to have several outliers. However, further analysis is typically required because univariate analysis doesn’t always provide the full picture of what may be going on. That is why bivariate (analysis of 2 variables) and multivariate analyses (analysis of 3 or more variables) are also important.

# %%
category_list = ["Category","Type","Content Rating","Genres"]    

for category in category_list:
# Create subplots with 1 row and 2 columns
    fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(18, 6))

    # Plot 1: Countplot
    sns.countplot(data=df, x=category, ax=axes[0])
    axes[0].set_xlabel('{}'.format(category.capitalize()), fontsize=15)
    axes[0].set_ylabel('Count of {}'.format(category.capitalize()), fontsize=15)
    axes[0].set_title('Count Plot of {}'.format(category.capitalize()), fontsize=20)
    axes[0].set_xticklabels(axes[0].get_xticklabels(), rotation=90)

    # Plot 2: Pie Chart
    #type_group = df.groupby(category).count()
    #type_group = type_group.reset_index()

    type_group = df.groupby(category).size().reset_index(name='Count')
    type_group = type_group.sort_values(by='Count', ascending=False).head(20) # to visualize most frequent 20 categories

    axes[1].pie(type_group[type_group.columns[1]], labels=type_group[category],labeldistance=1.2)
    axes[1].set_title('Pie Chart of {}'.format(category.capitalize()), fontsize=15)

    # Adjust the layout to prevent overlapping labels
    plt.tight_layout()

    # Show the plots
    plt.show()

# %% [markdown]
# ### ANALYIS

# %% [markdown]
# In this section, after visualization technics, the information will be gathered from this visualizations.

# %%
For Numeric values, some values

# %% [markdown]
# Only 6.7% apps scored below 3.5, it means that most of the apps get score between

# %%
df[df['Rating']<3.5].shape[0]/df.shape[0]*100
# Out:
# 6.7619926199261995

# %%
df[df['Rating']==5.00].shape[0]/df.shape[0]*100
# Out:
# 2.5276752767527677

# %%
df[df['Rating']==5.00]
# Out:
#                                               App   Category  Rating  Reviews  \
# 329                  Hojiboy Tojiboyev Life Hacks     COMICS     5.0     15.0
# 612                 American Girls Mobile Numbers     DATING     5.0      5.0
# 615                                  Awake Dating     DATING     5.0      2.0
# 633                         Spine- The dating app     DATING     5.0      5.0
# 636    Girls Live Talk - Free Text and Video Chat     DATING     5.0      6.0
# ...                                           ...        ...     ...      ...
# 10720                           Mad Dash Fo' Cash       GAME     5.0     14.0
# 10741                       GKPB FP Online Church  LIFESTYLE     5.0     32.0
# 10775                            Monster Ride Pro       GAME     5.0      1.0
# 10819                             Fr. Daoud Lamei     FAMILY     5.0     22.0
# 10836            Fr. Mike Schmitz Audio Teachings     FAMILY     5.0      4.0
#
# ...

# %%
df[df['Type']=='Paid']["Rating"].min()
# Out:
# 1.0

# %%
df[df['Reviews']>10000000]
# Out:
#                                                     App       Category  \
# 335            Messenger – Text and Video Chat for Free  COMMUNICATION
# 336                                  WhatsApp Messenger  COMMUNICATION
# 342                                     Viber Messenger  COMMUNICATION
# 378         UC Browser - Fast Download Private & Secure  COMMUNICATION
# 381                                  WhatsApp Messenger  COMMUNICATION
# ...                                                 ...            ...
# 6449                        BBM - Free Calls & Messages  COMMUNICATION
# 7536  Security Master - Antivirus, VPN, AppLock, Boo...          TOOLS
# 7937                                     Shadow Fight 2           GAME
# 8894  Cache Cleaner-DU Speed Booster (booster & clea...          TOOLS
# 8896  DU Battery Saver - Battery Charger & Battery Life          TOOLS
#
#       Rating     Reviews     Size      Installs  Type  Price Content Rating  \
# ...

# %%
review_dist = df[df['Reviews']<1000000]

plt.figure(figsize= (12,6))
ax = sns.boxplot(data = review_dist, x= review_dist["Reviews"])
ax.set_title('Box of Plot', fontsize= 20)
plt.ticklabel_format(style='plain', axis='x')

# %% [markdown]
# So, review numbers can be really high and even if it's filtered, finding a good box plot and distribution without outliers are not possible. So, it's hard to comment for this variable. Number of review column can be valueable for the bivariate analysis

# %% [markdown]
# And also, App size can not be important metric to measure. Maybe following sections, high size of apps affects the installation number can be questionere

# %% [markdown]
# ### BIVARIATE ANALYSIS

# %%
sns.scatterplot(data = df, x= df["Rating"], y= df['Installs'])
# Out:
# <Axes: xlabel='Rating', ylabel='Installs'>

# %%
pd.crosstab(index= df['Installs'], columns= df['Category'])
# Out:
# Category      ART_AND_DESIGN  AUTO_AND_VEHICLES  BEAUTY  BOOKS_AND_REFERENCE  \
# Installs
# 0.000000e+00               1                  0       0                    0
# 1.000000e+00               0                  1       0                    1
# 5.000000e+00               0                  2       0                    7
# 1.000000e+01               0                  5       0                   19
# 5.000000e+01               0                  1       1                    3
# 1.000000e+02               1                  6       5                    7
# 5.000000e+02               0                  3       1                    9
# 1.000000e+03               3                  8       1                   34
# 5.000000e+03               5                  2       3                   16
# 1.000000e+04              11                  6      13                   25
# 5.000000e+04               6                  5       5                   12
# ...

# %%
sns.pairplot( data = df)
# Out:
# /opt/homebrew/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
plt.figure(figsize= (12,6))
ax = sns.barplot(data = df,x=df['Category'],y=df['Rating'],estimator = np.median, )
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
# Out:
# [Text(0, 0, 'ART_AND_DESIGN'),
#  Text(1, 0, 'AUTO_AND_VEHICLES'),
#  Text(2, 0, 'BEAUTY'),
#  Text(3, 0, 'BOOKS_AND_REFERENCE'),
#  Text(4, 0, 'BUSINESS'),
#  Text(5, 0, 'COMICS'),
#  Text(6, 0, 'COMMUNICATION'),
#  Text(7, 0, 'DATING'),
#  Text(8, 0, 'EDUCATION'),
#  Text(9, 0, 'ENTERTAINMENT'),
#  Text(10, 0, 'EVENTS'),
#  Text(11, 0, 'FINANCE'),
#  Text(12, 0, 'FOOD_AND_DRINK'),
#  Text(13, 0, 'HEALTH_AND_FITNESS'),
#  Text(14, 0, 'HOUSE_AND_HOME'),
#  Text(15, 0, 'LIBRARIES_AND_DEMO'),
#  Text(16, 0, 'LIFESTYLE'),
#  Text(17, 0, 'GAME'),
#  Text(18, 0, 'FAMILY'),
#  Text(19, 0, 'MEDICAL'),
#  Text(20, 0, 'SOCIAL'),
#  Text(21, 0, 'SHOPPING'),
#  Text(22, 0, 'PHOTOGRAPHY'),
#  Text(23, 0, 'SPORTS'),
#  Text(24, 0, 'TRAVEL_AND_LOCAL'),
#  Text(25, 0, 'TOOLS'),
#  Text(26, 0, 'PERSONALIZATION'),
#  Text(27, 0, 'PRODUCTIVITY'),
#  Text(28, 0, 'PARENTING'),
#  Text(29, 0, 'WEATHER'),
#  Text(30, 0, 'VIDEO_PLAYERS'),
#  Text(31, 0, 'NEWS_AND_MAGAZINES'),
# ...

# %%
plt.figure(figsize= (12,6))
ax = sns.boxplot( data = df, x= df['Category'] ,  y= df["Rating"])
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
# Out:
# [Text(0, 0, 'ART_AND_DESIGN'),
#  Text(1, 0, 'AUTO_AND_VEHICLES'),
#  Text(2, 0, 'BEAUTY'),
#  Text(3, 0, 'BOOKS_AND_REFERENCE'),
#  Text(4, 0, 'BUSINESS'),
#  Text(5, 0, 'COMICS'),
#  Text(6, 0, 'COMMUNICATION'),
#  Text(7, 0, 'DATING'),
#  Text(8, 0, 'EDUCATION'),
#  Text(9, 0, 'ENTERTAINMENT'),
#  Text(10, 0, 'EVENTS'),
#  Text(11, 0, 'FINANCE'),
#  Text(12, 0, 'FOOD_AND_DRINK'),
#  Text(13, 0, 'HEALTH_AND_FITNESS'),
#  Text(14, 0, 'HOUSE_AND_HOME'),
#  Text(15, 0, 'LIBRARIES_AND_DEMO'),
#  Text(16, 0, 'LIFESTYLE'),
#  Text(17, 0, 'GAME'),
#  Text(18, 0, 'FAMILY'),
#  Text(19, 0, 'MEDICAL'),
#  Text(20, 0, 'SOCIAL'),
#  Text(21, 0, 'SHOPPING'),
#  Text(22, 0, 'PHOTOGRAPHY'),
#  Text(23, 0, 'SPORTS'),
#  Text(24, 0, 'TRAVEL_AND_LOCAL'),
#  Text(25, 0, 'TOOLS'),
#  Text(26, 0, 'PERSONALIZATION'),
#  Text(27, 0, 'PRODUCTIVITY'),
#  Text(28, 0, 'PARENTING'),
#  Text(29, 0, 'WEATHER'),
#  Text(30, 0, 'VIDEO_PLAYERS'),
#  Text(31, 0, 'NEWS_AND_MAGAZINES'),
# ...

# %%
plt.figure(figsize= (12,6))
ax = sns.boxplot( data = df, x= df['Type'] ,  y= df["Rating"])
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
# Out:
# [Text(0, 0, 'Free'), Text(1, 0, 'Paid')]

# %%
app_val_corr = df.corr()
heatmap = sns.heatmap(app_val_corr, vmin=-1, vmax=1, annot=True)
# Out:
# /var/folders/j9/scnjt0d57q3_lzqgdfj4j43r0000gn/T/ipykernel_56016/502807191.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   app_val_corr = df.corr()

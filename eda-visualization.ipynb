# %%
# import necessary packages

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('dataset/transformed-googleplaystore.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          10841 non-null  float64
#  3   Reviews         10841 non-null  float64
#  4   Size            10841 non-null  float64
#  5   Installs        10841 non-null  float64
#  6   Type            10841 non-null  object
#  7   Price           10841 non-null  float64
#  8   Content Rating  10841 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10840 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(5), object(8)
# memory usage: 1.1+ MB

# %%
df.describe()
# Out:
#              Rating       Reviews           Size      Installs         Price
# count  10841.000000  1.084100e+04   10841.000000  1.084100e+04  10841.000000
# mean       4.193338  4.443887e+05   20347.887178  1.546291e+07      1.027273
# std        0.499557  2.927728e+06   21601.967928  8.502557e+07     15.948971
# min        1.000000  0.000000e+00       8.500000  0.000000e+00      0.000000
# 25%        4.100000  3.800000e+01    6041.600000  1.000000e+03      0.000000
# 50%        4.200000  2.094000e+03   11264.000000  1.000000e+05      0.000000
# 75%        4.500000  5.479800e+04   26624.000000  5.000000e+06      0.000000
# max       19.000000  7.815831e+07  102400.000000  1.000000e+09    400.000000

# %%
df.describe(include='object')
# Out:
#            App Category   Type Content Rating Genres Last Updated  \
# count    10841    10841  10841          10841  10841        10840
# unique    9660       34      2              6    120         1377
# top     ROBLOX   FAMILY   Free       Everyone  Tools   2018-08-03
# freq         9     1972  10041           8715    842          326
#
#                Current Ver Android Ver
# count                10833       10838
# unique                2832          33
# top     Varies with device  4.1 and up
# freq                  1459        2451

# %%
fig, ax = plt.subplots(3,2,figsize=(10,10))

        
ax[0,0].boxplot(df['Rating'])
ax[0,0].set_xlabel("Rating")

ax[0,1].boxplot(df['Reviews'])
ax[0,1].set_ylabel("Reviews")

ax[1,0].boxplot(df['Size'])
ax[1,0].set_ylabel("Size")

ax[1,1].boxplot(df['Installs'])
ax[1,1].set_ylabel("Installs")

ax[2,0].boxplot(df['Price'])
ax[2,0].set_ylabel("Price")

plt.show()

# %%
sns.violinplot(x="Type",y="Rating",  data=df, palette="muted")
plt.show()
sns.violinplot(x="Type",y="Reviews",  data=df, palette="muted")
plt.show()
sns.violinplot(x="Type",y="Size",  data=df, palette="muted")
plt.show()
sns.violinplot(x="Type",y="Installs",  data=df, palette="muted")
plt.show()
sns.violinplot(x="Type",y="Price",  data=df, palette="muted")
plt.show()

# %%
Rating	Reviews	Size	Installs	Price

# %%
for column in df.columns:
    if df[column].dtypes=='float64': #for numeric attributes, not datetime
        sns.set(rc={'figure.figsize':(10,6)})
        sns.catplot(y=column, data=df, kind="box")
        plt.xticks(rotation=90)
        plt.title("Box Plot of {}".format(column.capitalize()),  fontsize=17)
        plt.show()
# Out:
# /opt/homebrew/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# /opt/homebrew/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# /opt/homebrew/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# /opt/homebrew/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# /opt/homebrew/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.catplot(x="Category", data=df, kind="count")
sns.catplot(x="Type", data=df, kind="count")
sns.catplot(x="Genres", data=df, kind="count")
sns.catplot(x="Rating", data=df, kind="count")


plt.show()
# Out:
# /opt/homebrew/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# /opt/homebrew/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# /opt/homebrew/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# /opt/homebrew/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
App	Category	Type	Content Rating	Genres	Last Updated	Current Ver	Android Ver

# %%
fig, ax = plt.subplots(3,2,figsize=(10,10))

        
ax[0,0].hist(df['Reviews'], color='r')
ax[0,0].set_xlabel("Reviews")
ax[0,0].set_ylabel("# of observations")

ax[0,1].hist(df['Rating'], color='r')
ax[0,1].set_xlabel("Rating")
ax[0,1].set_ylabel("# of observations")


plt.show()
